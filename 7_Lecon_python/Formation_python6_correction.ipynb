# %% [markdown]
# #    PARTIE 2 : VARIABLES

# %% [markdown]
# ##    Introduction aux variables

# %% [markdown]
# ### Création d'une variable

# %% [markdown]
# Une variable est un conteneur qui stocke une valeur. Pour créer une variable en Python, il suffit de lui donner un nom et de lui affecter une valeur.
#
# Voici un exemple de code Python qui crée une variable :

# %%
x = 5

# %% [markdown]
# ### Modification d'une variable

# %% [markdown]
# Une variable peut être modifiée en lui affectant une nouvelle valeur.
#
# Voici un exemple de code Python qui modifie une variable :

# %%
x = 5
x = x + 1
print(x)  # 6

# %% [markdown]
# ### Affichage d'une variable

# %% [markdown]
# Pour afficher la valeur d'une variable en Python, il suffit d'utiliser la fonction print() et de passer la variable en argument.
#
# Voici un exemple de code Python qui affiche la valeur d'une variable :

# %%
x = 5
print(x)  # 5

# %% [markdown]
# ## Types de données

# %% [markdown]
# ### Entiers

# %% [markdown]
# Les entiers sont des nombres entiers, sans virgule.
#
# Voici un exemple de code Python qui utilise des entiers :

# %%
x = 5
y = 10
z = x + y
print(z)  # 15

# %% [markdown]
# ### Virgules flottantes

# %% [markdown]
# Les virgules flottantes sont des nombres à virgule.
#
# Voici un exemple de code Python qui utilise des virgules flottantes :

# %%
x = 5.5
y = 10.2
z = x + y
print(z)  # 15.7

# %% [markdown]
# ### Chaînes de caractères

# %% [markdown]
# Les chaînes de caractères sont des séquences de caractères.
#
# Voici un exemple de code Python qui utilise des chaînes de caractères :

# %%
x = "Bonjour"
y = "monde"
z = x + " " + y
print(z)  # "Bonjour monde"

# %% [markdown]
# ### Booléens

# %% [markdown]
# Les booléens sont des valeurs de vérité, qui peuvent être soit True, soit False.
#
# Voici un exemple de code Python qui utilise des booléens :

# %%
x = True
y = False
z = x and y
print(z)  # False

# %% [markdown]
# ## Fonctions utiles

# %% [markdown]
# ### Fonction type()

# %% [markdown]
# La fonction type() permet de connaître le type d'une variable.
#
# Voici un exemple de code Python qui utilise la fonction type() :

# %%
x = 5
print(type(x))  # <class 'int'>

# %% [markdown]
# ### Fonction str()

# %% [markdown]
# La fonction str() permet de convertir une variable en chaîne de caractères.
#
# Voici un exemple de code Python qui utilise la fonction str() :

# %%
x = 5
print(str(x))  # "5"

# %% [markdown]
# ### Fonction int()

# %% [markdown]
# La fonction int() permet de convertir une variable en entier.
#
# Voici un exemple de code Python qui utilise la fonction int() :

# %%
x = "5"
print(int(x))  # 5

# %% [markdown]
# ### Fonction float()

# %% [markdown]
# La fonction float() permet de convertir une variable en virgule flottante.
#
# Voici un exemple de code Python qui utilise la fonction float() :

# %%
x = "5.5"
print(float(x))  # 5.5

# %% [markdown]
# ### Fonction input()

# %% [markdown]
# La fonction input() permet de lire une valeur depuis l'entrée standard (clavier).
#
# Voici un exemple de code Python qui utilise la fonction input() :

# %%
x = input("Entrez une valeur : ")
print("Vous avez entré : " + x)

# %% [markdown]
# ## Interactions avec les chaines de caractère/string

# %% [markdown]
# La chaîne Python est une collection ordonnée de caractères utilisée pour stocker et représenter des informations textuelles. Du point de vue fonctionnel, les chaînes peuvent être utilisées pour représenter à peu près tout ce qui peut être encodé en texte : symboles, mots, nombres, contenu de fichiers, etc.
#
# Les chaînes sont créées en plaçant des guillemets (simples ou doubles) autour de la séquence de caractères donnée. Les chaînes sont des séquences immuables, ce qui signifie que l'ordre positionnel des caractères qu'elles contiennent, de gauche à droite, ne peut pas être modifié en place. Elles prennent en charge des opérations telles que :
#
#     la concaténation (combinaison de chaînes)
#     le découpage (extraction de sections)
#     l'indexation (recherche par décalage)
#     et la liste continue...
#
# Python fournit également un ensemble de méthodes de chaîne qui mettent en œuvre des tâches spécifiques aux chaînes courantes, ainsi que des modules pour des tâches de traitement de texte plus avancées, telles que la correspondance de motifs. Créons quelques chaînes !

# %% [markdown]
# ### RAPPEL

# %%
nom_chien = 'Mimi'

nom_chien
# Out:
# 'Mimi'

# %%
type(nom_chien)
# Out:
# str

# %% [markdown]
# ### aller à la ligne

# %% [markdown]
# L'utilisation de guillemets doubles pour créer la chaîne nous permet d'intégrer des éléments comme une apostrophe dans la chaîne.
# Si l'on souhaite garder les guillements simples, l'anti-slash \ permet d'annuler l'effet de l'apostrophe.

# %%
phrase = "Je m'appelle Machin Chouette"

phrase
# Out:
# "Je m'appelle Machin Chouette"

# %%
phrase = 'Je m\'appelle Machin Chouette'

phrase
# Out:
# "Je m'appelle Machin Chouette"

# %% [markdown]
# Le caractère antislash offre des fonctionnalités de formatage de chaînes supplémentaires. Tenez compte des commandes suivantes :
#
#     \t - insère une tabulation dans la chaîne
#     \n - insère une nouvelle ligne dans la chaîne
#
# Ce sont probablement celles que vous utiliserez le plus, mais il en existe d'autres.

# %%
phrase_a_la_ligne = "Un matin, \nje me suis levé"

phrase_a_la_ligne
# Out:
# 'Un matin, \nje me suis levé'

# %%
print(phrase_a_la_ligne)
# Out:
# Un matin,
# je me suis levé

# %% [markdown]
# Sinon on peut aller à la ligne avec les triples guillemets

# %%
phrase_triple = """Un soir,
Je me suis couché."""

phrase_triple
# Out:
# 'Un soir,\nJe me suis couché.'

# %%
print(phrase_triple)
# Out:
# Un soir,
# Je me suis couché.

# %% [markdown]
# ### Méthodes pour les string

# %% [markdown]
# Nous pouvons vérifier si un caractère se trouve dans une chaîne en utilisant **in**. Il existe également **not in**. Le résultat renvoie un booléen.

# %%
prenom = "Patrick"

"c" in prenom
# Out:
# True

# %%
"Pat" in prenom
# Out:
# True

# %%
"T" not in prenom
# Out:
# True

# %% [markdown]
# Python offre de nombreuses fonctions pour manipuler les chaînes de caractères:

# %%
mystring = "bonjour le monde !     "

# %% [markdown]
# Nous pouvons voir le nombre de caractères dans la chaîne en utilisant la fonction len() intégrée. Notez que l'espace compte comme un caractère.

# %%
# combien de caractères dans la chaine ?
len(mystring)
# Out:
# 23

# %% [markdown]
# Passer en majuscule le premier caractère de la liste

# %%
print(mystring.capitalize())  # "Bonjour le monde!     "
# Out:
# Bonjour le monde !

# %% [markdown]
# Supprimer les espaces en début et fin de chaine

# %%
print(mystring.strip())  # "Bonjour le monde!"
# Out:
# bonjour le monde !

# %% [markdown]
# Passer tout en majuscule

# %%
print(mystring.upper())  # "BONJOUR LE MONDE!"
# Out:
# BONJOUR LE MONDE !

# %% [markdown]
# Passer tout en minuscule

# %%
print(mystring.lower())  # "BONJOUR LE MONDE!"
# Out:
# bonjour le monde !

# %% [markdown]
# Compter le nombre d'itération d'un caractère dans une chaine

# %%
print(mystring.count("o"))  # 3
# Out:
# 3

# %% [markdown]
# Localiser un/des caractère(s) dans une chaine (fournit l'indice)

# %%
print(mystring.find("monde"))  # 7
# Out:
# 11

# %%
print(mystring.find("!"))
# Out:
# 17

# %% [markdown]
# ### DECOUPAGE ET INDEXATION

# %% [markdown]
# Chaque chaîne peut être considérée comme un ordre de gauche à droite d'une séquence de caractères. Par conséquent, ces caractères peuvent être accédés via cet ordre. Pour les chaînes et autres objets Python, l'indexation commence à 0 et se termine à len()-1, et les indices que vous souhaitez accéder sont toujours entre crochets. Faisons du slicing !

# %%
s = "spam"

# %%
# premier caractère
s[0]
# Out:
# 's'

# %%
# dernier caractère
s[-1]
# Out:
# 'm'

# %% [markdown]
# Nous pouvons même découper des morceaux d'une chaîne en séparant les indices de début et de fin par un ":". L'indice de fin n'est pas inclus.

# %%
salutations = "Bonjour à tous"

# %%
# récupérer le premier mot (à partir de l'indexation 0 ou vide)

salutations[0:7], salutations[:7]
# Out:
# ('Bonjour', 'Bonjour')

# %% [markdown]
# Rappelez-vous que les chaînes sont immuables, nous ne pouvons donc pas les modifier en place. Par conséquent, l'opération suivante entraîne une erreur.

# %%
nom_erreur = "Lusie"

# vous ne pouvez pas changer une seule valeur dans la chaine
nom_erreur[2] = "c"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4d0242515d5b> in <module>
#       2
#       3 # vous ne pouvez pas changer une seule valeur dans la chaine
# ----> 4 nom_erreur[2] = "c"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # Partie 3 : Opérations possibles

# %% [markdown]
# Pour l'instant, nous devrons effectuer cette correction via la concaténation. Ce sera notre premier exemple de polymorphisme ; l’idée que certains opérateurs agissent différemment selon le type d’objets sur lesquels ils agissent. Pour les nombres, l’opérateur « + » effectue une addition. Pour les chaînes, l’opération « + » concatène la chaîne. Notez que l’opérateur « + » pour les chaînes ne suit pas la propriété commutative car l’ordre a de l’importance. Donc, nous n’avons pas a + b = b + a si a et b sont des chaînes.

# %%
trois_premiers = "abc"
trois_derniers = "def"

#concaténation
suite = trois_premiers + trois_derniers

suite
# Out:
# 'abcdef'

# %%
# concaténation et découpage

prenom = "Albus"
deuxieme_prenom = "Perceval"
nom = "Dumbledore"

# récupérer les initiales
initiales = prenom[0]+deuxieme_prenom[0]+nom[0]

initiales
# Out:
# 'APD'

# %% [markdown]
# ## Opérations arithmétiques et d'affectation

# %% [markdown]
# Les opérations arithmétiques en Python sont les suivantes :
#
#     Addition : +
#     Soustraction : -
#     Multiplication : *
#     Division : /
#     Modulo : %
#     Exponentiation : **
#     Division entière : //
#     Valeur absolue : abs()
#     Racine carrée : sqrt()
#
# Les opérations d'affectation en Python sont les suivantes :
#
#     Affectation simple : =
#     Affectation multiple : +=, -=, *=, /=, %=, **=, //=
#
# Voici un exemple de code Python qui utilise des opérations arithmétiques et d'affectation :

# %%
x = 5
x += 1
print(x)  # 6

# %%
x = 5
x *= 2
print(x)  # 10

# %%
x = 5
x /= 2
print(x)  # 2.5

# %%
x = 5
x %= 2
print(x)  # 1

# %%
x = 5
x **= 2
print(x)  # 25

# %%
x = 5
x //= 2
print(x)  # 2

# %%
#valeur absolue
abs(-4)

# %%
#Importer depuis un package la méthode de la racine carrée
import math
math.sqrt(36)

# %% [markdown]
# Sur les strings

# %%
# *
prenom*2
# Out:
# 'AlbusAlbus'

# %% [markdown]
# Que se passe-t-il lorsque nous essayons d'utiliser l'opérateur "+" entre une chaîne et un entier ?

# %%
str_num = "6"
num = 5

str_num + num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-8055d5044a4f> in <module>
#       2 num = 5
#       3
# ----> 4 str_num + num
#
# TypeError: can only concatenate str (not "int") to str

# %%
# polymorphisme de l'addition
str(num) + str_num, num + int(str_num)
# Out:
# ('56', 11)

# %% [markdown]
# ## Opérateurs de comparaison

# %% [markdown]
# Les opérateurs de comparaison en Python sont les suivants :
#
#     Égalité : ==
#     Inégalité : !=
#     Infériorité : <
#     Supériorité : >
#     Infériorité ou égalité : <=
#     Supériorité ou égalité : >=
#
# Voici un exemple de code Python qui utilise des opérateurs de comparaison :

# %%
x = 5
y = 10

# %%
print(x == y)  # False

# %%
print(x != y)  # True

# %%
print(x < y)  # True

# %%
print(x > y)  # False

# %%
print(x <= y)  # True

# %%
print(x >= y)  # False

# %% [markdown]
# # Partie 4 : Objets à stockage multiple

# %% [markdown]
# ## Listes

# %% [markdown]
# Les listes sont utilisées pour stocker une collection d'objets en Python.
#
# Elles sont délimitées par des crochets **[]**.
#
# *Tous types de données* peuvent être stockés dans une liste, y compris des listes imbriquées.

# %%
student = ["Olivia", "Liam", "Ava", "Noah", "Sophia", "Ethan", "Isabella", "Mason", "Charlotte", "James"]

# %% [markdown]
# Les éléments d'une liste peuvent être accédés en utilisant leur *indice*, qui commence à 0 et va jusqu'à len(liste) - 1.
#
# Les indices négatifs peuvent également être utilisés pour accéder aux éléments à partir de la fin de la liste.
#
# La fonction len() peut être utilisée pour déterminer le **nombre d'éléments** dans une liste.

# %%
# Nombre d'éléments dans une liste

print(len(student)) #10
# Out:
# 10

# %%
# trouver l'index d'un élément

student.index("Olivia")
# Out:
# 0

# %%
# Accéder aux éléments d'une liste

print(student[0])  # Olivia
# Out:
# Olivia

# %%
print(student[-1])  # James
# Out:
# James

# %%
print(student[3:6]) # ['Noah', 'Sophia', 'Ethan']
# Out:
# ['Noah', 'Sophia', 'Ethan']

# %%
# vérifier la présence d'un élément dans la liste
"Isabella" in student
# Out:
# True

# %% [markdown]
# Les éléments d'une liste peuvent être **modifiés** en utilisant leur indice et en assignant une nouvelle valeur. (NON IMMUABLE)

# %%
# Modifier un élément d'une liste

student[1] = "Abby"
print(student)
# Out:
# ['Olivia', 'Abby', 'Ava', 'Noah', 'Sophia', 'Ethan', 'Isabella', 'Mason', 'Charlotte', 'James']

# %% [markdown]
# Les nouvelles valeurs peuvent être **ajoutées** à une liste en utilisant la méthode append() ou insert().

# %%
# Ajouter un élément à une liste en dernière position

student.append("New Student")
print(student)
# Out:
# ['Olivia', 'Abby', 'Ava', 'Noah', 'Sophia', 'Ethan', 'Isabella', 'Mason', 'Charlotte', 'James', 'New Student']

# %%
# Ajouter un élément à une liste à une indexation précise
student.insert(2, "New Student 2")
print(student)
# Out:
# ['Olivia', 'Abby', 'New Student 2', 'Ava', 'Noah', 'Sophia', 'Ethan', 'Isabella', 'Mason', 'Charlotte', 'James', 'New Student']

# %%
# insérer plusieurs éléments à la fois en ajoutant une liste

student.extend(["Juliette", "Roméo"])

print(student)
# Out:
# ['Olivia', 'Abby', 'New Student 2', 'Ava', 'Noah', 'Sophia', 'Ethan', 'Isabella', 'Mason', 'Charlotte', 'James', 'New Student', 'Juliette', 'Roméo']

# %% [markdown]
# Les éléments peuvent être **supprimés** d'une liste en utilisant la méthode remove() ou pop().

# %%
# Supprimer un élément d'une liste

student.remove("Ava")
print(student)
# Out:
# ['Olivia', 'Abby', 'New Student 2', 'Noah', 'Sophia', 'Ethan', 'Isabella', 'Mason', 'Charlotte', 'James', 'New Student', 'Juliette', 'Roméo']

# %%
# supprimer un élément précis de la liste en indiquant son index
student.pop(2)
print(student)
# Out:
# ['Olivia', 'Abby', 'Noah', 'Sophia', 'Ethan', 'Isabella', 'Mason', 'Charlotte', 'James', 'New Student', 'Juliette', 'Roméo']

# %%
# supprimer le dernier élément de la liste
student.pop()
print(student)
# Out:
# ['Olivia', 'Abby', 'Noah', 'Sophia', 'Ethan', 'Isabella', 'Mason', 'Charlotte', 'James', 'New Student', 'Juliette']

# %% [markdown]
# La méthode sort() peut être utilisée pour **trier** les éléments d'une liste.

# %%
# Trier les éléments d'une liste

student.sort()

print(student)
# Out:
# ['Abby', 'Charlotte', 'Ethan', 'Isabella', 'James', 'Juliette', 'Mason', 'New Student', 'Noah', 'Olivia', 'Sophia']

# %% [markdown]
# La méthode reverse() permet d'**inverser** l'ordre des éléments.

# %%
student.reverse()
print(student)
# Out:
# ['Sophia', 'Olivia', 'Noah', 'New Student', 'Mason', 'Juliette', 'James', 'Isabella', 'Ethan', 'Charlotte', 'Abby']

# %% [markdown]
# La méthode **count()** permet d'avoir le nombre d'itération d'un élément dans une liste.

# %%
student.count("Mason")
# Out:
# 1

# %% [markdown]
# Les listes sont des collections ordonnées d'éléments. Elles peuvent contenir des éléments de **différents types**.

# %%
mylist = [1, 2, 3, "Bonjour", True]
print(mylist)
# Out:
# [1, 2, 3, 'Bonjour', True]

# %% [markdown]
# On peut créer une liste à partir d'une phrase avec la méthode **split()** autour d'un caractère précisé.

# %%
# enregistrer chaque mot dans la liste

ligne = 'Je suis allée au restaurant.'

phrase = ligne.split(' ')
phrase
# Out:
# ['Je', 'suis', 'allée', 'au', 'restaurant.']

# %% [markdown]
# ## Tuples

# %% [markdown]
# Les tuples sont similaires aux listes, mais ils sont **immuables**, ce qui signifie qu'ils *ne peuvent pas être modifiés une fois créés.
#
# Les tuples sont délimités par des parenthèses **()**.
#
# Les éléments d'un tuple peuvent être accédés en utilisant leur *indice*, qui commence à 0 et va jusqu'à len(tuple) - 1.
#
# Les tuples sont souvent utilisés pour stocker des paires de valeurs, telles que des coordonnées x, y.

# %% [markdown]
# ### Interactions possibles

# %%
# Créer un tuple

coordinates = (1, 2, 3, 9, 6, 5, 2)

print(coordinates)
# Out:
# (1, 2, 3, 9, 6, 5, 2)

# %% [markdown]
# Il est possible de créer un tuple *à un élément*, toutefois il faut indiquer une virgule afin de s'assurer que cela ne soit pas confondu avec une variable

# %%
tuple_simple = (4,)
tuple_simple
# Out:
# (4,)

# %%
# Accéder aux éléments d'un tuple

print(coordinates[0])  # 1
# Out:
# 1

# %%
print(coordinates[-1])  # 2
# Out:
# 2

# %%
# déterminer la longueur du tuple

len(coordinates)
# Out:
# 7

# %%
# compter le nombre d'occurence d'un élément
coordinates.count(9)
# Out:
# 1

# %%
# retourne l'index de la première occurence d'un élément
coordinates.index(2)
# Out:
# 1

# %%
# vérifier qu'un élément fasse partie du tuple

7 in coordinates
# Out:
# False

# %% [markdown]
# ### Créer un tuple à partir d'un autre

# %% [markdown]
# On **ne peut pas modifier un tuple** !
# Toutefois, on peut en créer un à partir d'un autre.

# %%
# ajouter des éléments d'un tuple à un autre

coordonnees = coordinates.__add__((4,))
print(coordinates)
print(coordonnees)
# Out:
# (1, 2, 3, 9, 6, 5, 2)
# (1, 2, 3, 9, 6, 5, 2, 4)

# %%
# concaténer des tuples

tout = coordinates + coordonnees

tout
# Out:
# (1, 2, 3, 9, 6, 5, 2, 1, 2, 3, 9, 6, 5, 2, 4)

# %%
# concaténer des fragments de tuples

partiel = coordinates[:5]+ coordonnees[3:]
partiel
# Out:
# (1, 2, 3, 9, 6, 9, 6, 5, 2, 4)

# %%
# répéter des tuples

multiple = coordinates*3

multiple
# Out:
# (1, 2, 3, 9, 6, 5, 2, 1, 2, 3, 9, 6, 5, 2, 1, 2, 3, 9, 6, 5, 2)

# %% [markdown]
# ## Dictionnaires

# %% [markdown]
# Les dictionnaires sont des collections de paires clé-valeur. Chaque clé doit être unique et immuable.
# Structure : {clé1 : valeur1, clé2 : valeur2}
#
# Ils permettent de donner un accès facile à des données organisées de manière structurée et logique. Les clés ainsi que les valeurs peuvent être des données de différents types.
#
# Il est aisé de modifier, supprimer ou ajouter des éléments dans un dictionnaire.
#
#     Exemples d'application :
#
# - Stockage d'informations sur des personnes
#
# personne = {"nom": "Alice",
#             "age": 30,
#             "ville": "Paris"}
#
# - Configuration de paramètres
#
# parametres = {"taille": 10,
#               "couleur": "rouge",
#               "mode": "normal"}

# %%
# déclaration d'un dictionnaire

ID = {"nom": "Alice", 
      "age": 30, 
      "ville": "Paris",
      "pays" : "France",
      "Description" : "blonde"
     }

# %% [markdown]
# Pour se souvenir de toutes les clés d'un dictionnaire, la méthode keys() fournit la liste des clés.

# %%
ID.keys()
# Out:
# dict_keys(['nom', 'age', 'ville', 'pays', 'Description'])

# %% [markdown]
# De même pour les valeurs, il y a la méthode values() qui fournit la liste des valeurs.

# %%
ID.values()
# Out:
# dict_values(['Alice', 30, 'Paris', 'France', 'blonde'])

# %% [markdown]
# Pour visualiser l'ensemble des binômes clé-valeur, la méthode item() permet de les réunir sous forme de tuple.

# %%
ID.items()
# Out:
# dict_items([('nom', 'Alice'), ('age', 30), ('ville', 'Paris'), ('pays', 'France'), ('Description', 'blonde')])

# %% [markdown]
# Pour appeler une valeur, il faut passer par sa clé.

# %%
# accéder aux valeurs

print(ID["age"])
print(ID["Hobby"])
# Out:
# 30
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-c62428c0714f> in <module>
#       2
#       3 print(ID["age"])
# ----> 4 print(ID["Hobby"])
#
# KeyError: 'Hobby'

# %% [markdown]
# ou avec la méthode get(), elle ne renvoie pas d'erreur si la clé n'existe pas, juste None

# %%
print(ID.get("ville"))
print(ID.get("Hobby"))
# Out:
# Paris
# None

# %% [markdown]
# Pour ajouter une valeur, il faut déclarer la nouvelle clé et sa valeur associée.

# %%
ID["sexe"] = "femme"

ID
# Out:
# {'nom': 'Alice',
#  'age': 30,
#  'ville': 'Paris',
#  'pays': 'France',
#  'Description': 'blonde',
#  'sexe': 'femme'}

# %% [markdown]
# Pour supprimer une valeur, on passe par sa clé.

# %%
del ID["age"]
ID
# Out:
# {'nom': 'Alice',
#  'ville': 'Paris',
#  'pays': 'France',
#  'Description': 'blonde',
#  'sexe': 'femme'}

# %% [markdown]
# Ou alors par la méthode pop() qui retourne la valeur de la clé, avant de la supprimer du dictionnaire

# %%
ID.pop('sexe')
ID
# Out:
# {'nom': 'Alice', 'ville': 'Paris', 'pays': 'France', 'Description': 'blonde'}

# %% [markdown]
# Pour modifier une valeur, appeler sa clé. Vous pouvez renseigner tout type de données (simple, liste, tuple)

# %%
ID["Description"] = ['blonde','yeux verts', 'cheveux longs']

ID
# Out:
# {'nom': 'Alice',
#  'ville': 'Paris',
#  'pays': 'France',
#  'Description': ['blonde', 'yeux verts', 'cheveux longs']}

# %% [markdown]
# ou alors avec la méthode update() qui fusionne les clés et les valeurs d'un dictionnaire dans un autre, en écrasant aveuglément les valeurs de la même clé.

# %%
ID2 = { "ville" : "Lyon", "nom" : "Fabrice"}

ID.update(ID2)
ID
# Out:
# {'nom': 'Fabrice',
#  'ville': 'Lyon',
#  'pays': 'France',
#  'Description': ['blonde', 'yeux verts', 'cheveux longs']}

# %% [markdown]
# # Partie 5 : Codons !

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# Nous souhaitons calculer la moyenne des notes d'un stagiaire.

# %%
#Les entrées :
student_name = input("Entrer le nom du stagiaire :")
note1 = input("Entrer la première note :")
note2 = input("Entrer la deuxième note :")
note3 = input("Entrer la troisième note :")
#Calculons la moyenne :
result = (note1 + note2 + note3)/3
print("La moyenne de " + student_name + "est de " + result)

# %%
#Si nous lançons de programme il tombe en erreur, détaillons ces erreurs :
#Nos inputs sont en string et nous voulons leur faire des opérations mathématiques.
#cela ne peut pas marcher. Modifions nos input afin qu'ils soient des nombres entiers :
#Utilisation d'une nouvelle fonction 'int' :
note1 = int(input("Entrer la première note :"))
note2 = int(input("Entrer la deuxième note :"))
note3 = int(input("Entrer la troisième note :"))
#cette fois-ci, le calcul est réalisable.
result = (note1 + note2 + note3)/3
#Affichons la réponse en n'oublions pas de basculer notre résulat en chaîne de caratères :
print("La moyenne de " + student_name + " est de " + str(result))

# %% [markdown]
# ## Exercice 2 : If

# %% [markdown]
# Nous souhaitons demander le contenu d'un porte monnaie, réaliser un achat de 50euros et obtenir le montant restant dans le porte-monnaie.

# %%
#Récolter une valeur de porte monnaie :
wallet = int(input("Entrer le nombre d'euro que vous possédez :"))
print("Vous avez actuellement", wallet, "euros")

#Créer un produit qui aura pour valeur 50euros :
produit = 50
print("Le produit vaut ", produit, "euros")

#Enlever au wallet le prix du produit :
wallet = wallet - produit
#Ou, aussi possible de faire :
#wallet -= produit

#afficher la nouvelle valeur :
print("Produit acheté !")
print("Il ne vous reste plus que" + str(wallet) + " euros.")

# %% [markdown]
# Il est probable que le montant indiqué soit inférieur à 50euros, et donc que le résultat final soit inférieur à 0.
# Nous souhaitons donc rédiger ce code à nouveau, afin qu'il indique que le produit ne pourra pas être acheté, si le montant est inférieur à 50€.

# %%
# Vérifier que le montant indiqué est inférieur à 50€

#Récolter une valeur de porte monnaie :
wallet = int(input("Entrer le nombre d'euro que vous possédez :"))

#Créer un produit qui aura pour valeur 50euros :
produit = 50

print(wallet>produit)

# %% [markdown]
# Rédigons notre condition
#
# *Rappel : opérateurs de comparaison : ==, !=, <, >, <=, >=*
#
# **A RETENIR**
#
# Syntaxe d'un bloc de condition en Python

# %% [raw]
# if condition :
#     bloc à exécuter
# elif condition2 :
#     bloc à exécuter
# else :
#     bloc à exécuter
#
# - elif et else sont optionnels
# - dans cette syntaxe, il n'y a pas de mot qui indique la fin de la condition if. Sa structure est marquée par les indentations !!!!!
# - else prend tous les cas opposés à la condition indiquée dans if

# %%
#Récolter une valeur de porte monnaie :
wallet = int(input("Entrer le nombre d'euro que vous possédez :"))

# %%
#Créer un produit qui aura pour valeur 50euros :
produit = 50

# si le montant est trop faible, arrêter les calculs
# si non, effectuer le calcul
if wallet < produit :
    print(f"Vous n'avez pas suffisamment d'argent pour acheter le produit à {produit} euros.")
else :
    #Enlever au wallet le prix du produit :
    wallet -= produit

    #afficher la nouvelle valeur :
    print("Produit acheté !")
    print("Il ne vous reste plus que" + str(wallet) + " euros.")

# %% [markdown]
# ## Exercice 3 : If

# %% [markdown]
# Nous allons créer un système de vérifiaction de mot de passe
# Vous savez, ces fameuses vérifications qui nous casse les pieds à chaque changement de mot de passe.
#
# Le code doit vérifier que votre mot de passe contient plus de 8 caractères.

# %%
password = input("Entrer votre mot de passe : ")
#Utilisation d'une nouvelle fonction 'len':
password_length = len(password)
#Vérifier si le mot de passe est inférieur à 8 caractères :
if password_length < 8:
    print("Mot de passe trop court !")
else:
    print("Mot de passe valide !")

# %% [markdown]
# Complexifions cette condition avec une condition intermédiaire : elif
# Le code doit indiquer que si le nombre de caractères est entre 8 et 12, le mot de passe est faible.

# %%
password = input("Entrer votre mot de passe : ")
#Utilisation d'une nouvelle fonction 'len':
password_length = len(password)
if password_length < 8:
    print("Mot de passe trop court !")
elif password_length >= 8 and password_length <= 12:   #Avec le raccourci 'ALT + ENTRÉE' on peut simplifier la condition.
    print("Mot de passe faible !")
else:
    print("Mot de passe valide !")

# %% [markdown]
# ## Exercice 4 : for

# %% [markdown]
# Découvrons l'intérêt d'utiliser des boucles
#
# Rédiger un code qui permet d'afficher à l'écran tous les éléments d'une liste d'emails.

# %%
liste = ["a@gmail.com", "b@gmail.com", "c@gmail.com", "d@gmail.com", "e@gmail.com"]

# %%
print(len(liste))
# Out:
# 5

# %%
print(liste[0])
print(liste[1])
print(liste[2])
print(liste[3])
print(liste[4])
# Out:
# a@gmail.com
# b@gmail.com
# c@gmail.com
# d@gmail.com
# e@gmail.com

# %% [markdown]
# Pour éviter les redondances, il suffit de créer la boucle suivante :
#
# *Rappel : boucle for quand on connait le nombre d'itérations, boucle while quand la fin dépend de la réalisation d'une condition*

# %% [raw]
# for i in range() :
#     bloc d'exécution

# %%
for i in range(len(liste)):
    print("Mail envoyé à " + liste[i])
# Out:
# Mail envoyé à a@gmail.com
# Mail envoyé à b@gmail.com
# Mail envoyé à c@gmail.com
# Mail envoyé à d@gmail.com
# Mail envoyé à e@gmail.com

# %% [markdown]
# Ce premier exemple parcourt tous les éléments de la liste selon leur index (de 0 à len()-1).
#
# Python est capable de parcourir un(e) liste/tuple/dictionnaire par lui-même.

# %%
for mail in liste :
    print("Mail envoyé à " + mail)
# Out:
# Mail envoyé à a@gmail.com
# Mail envoyé à b@gmail.com
# Mail envoyé à c@gmail.com
# Mail envoyé à d@gmail.com
# Mail envoyé à e@gmail.com

# %% [markdown]
# *ATTENTION*
# Ici la variable mail est variable **locale** et non globale. C'est-à-dire qu'elle est définie uniquement dans la boucle et qu'on ne peut pas l'appeler en dehors. En effet, une fois que la boucle est finie, la variable est détruite.

# %% [markdown]
# ## Exercice 5 : while

# %% [markdown]
# Il est possible que vous ne saviez pas le nombre d'itération de votre boucle. Vous pouvez être amenés à vouloir répéter une action jusqu'à ce qu'une condition soit vérifiée.
# Par exemple, vous passerez l'épreuve de conduite **tant que** vous n'avez pas obtenu votre permis.

# %% [markdown]
# Rédaction d'une boucle **while**

# %% [raw]
# while condition :
#     bloc à exécuter

# %% [markdown]
# la boucle sera exécutée tant que la condition est fausse/non vérifiée

# %% [markdown]
# Enoncé :
# Nous voulons savoir dans combien de temps notre salarié aura un salaire de 3000euros avec une augmentation de 78euros par an.

# %%
salary = 1500
years = 0
while salary < 3000:
    salary += 78
    years += 1
    print("Votre salaire actuel est de", salary, "euros.")
print("Vous mettrez ", years, "ans pour atteindre un salaire de plus de 3000 euros")
# Out:
# Votre salaire actuel est de 1578 euros.
# Votre salaire actuel est de 1656 euros.
# Votre salaire actuel est de 1734 euros.
# Votre salaire actuel est de 1812 euros.
# Votre salaire actuel est de 1890 euros.
# Votre salaire actuel est de 1968 euros.
# Votre salaire actuel est de 2046 euros.
# Votre salaire actuel est de 2124 euros.
# Votre salaire actuel est de 2202 euros.
# Votre salaire actuel est de 2280 euros.
# Votre salaire actuel est de 2358 euros.
# Votre salaire actuel est de 2436 euros.
# Votre salaire actuel est de 2514 euros.
# Votre salaire actuel est de 2592 euros.
# Votre salaire actuel est de 2670 euros.
# Votre salaire actuel est de 2748 euros.
# Votre salaire actuel est de 2826 euros.
# Votre salaire actuel est de 2904 euros.
# Votre salaire actuel est de 2982 euros.
# Votre salaire actuel est de 3060 euros.
# Vous mettrez  20 ans pour atteindre un salaire de plus de 3000 euros

# %% [markdown]
# Maintenant modifions le code pour qu'il nous donne notre salaire à la N.ième année. N à demander à l'utilisateur:

# %%
salary = 1500
years = 0
year_of_interest = int(input("De quelle annee voulez connaitre le salaire ? "))
while years < year_of_interest:
    salary += 78
    years += 1
print("Dans ", years, "ans, vous toucherez", salary)
# Out:
# De quelle annee voulez connaitre le salaire ? 5
# Dans  5 ans, vous toucherez 1890

# %% [markdown]
# ## Exercice 6

# %% [markdown]
# ### Module random

# %% [markdown]
# Random est un module intégré à Python qui permet de générer des nombres aléatoires. Il permet de faire appel à des fonctions spécifiques : random, randint, choice, shuffle

# %%
import random

# %% [markdown]
#     Générer un nombre aléatoire:
#
# La fonction principale du module random est random.random(). Elle renvoie un nombre flottant aléatoire compris entre 0 (inclus) et 1 (exclu).

# %%
nombre_aleatoire = random.random()
print(nombre_aleatoire)  # Affiche un nombre décimal entre 0 et 1
# Out:
# 0.6546579995455504

# %% [markdown]
#     Générer un entier aléatoire:
#
# Pour obtenir un entier aléatoire dans une plage spécifique, utilisez random.randint(a, b).

# %%
nombre_entier = random.randint(1, 10)  # Génère un entier entre 1 et 10 (inclus)
print(nombre_entier)
# Out:
# 9

# %% [markdown]
#     Choisir un élément aléatoire dans une liste:
#
# La fonction random.choice(sequence) permet de sélectionner un élément aléatoire dans une liste, une chaîne de caractères ou un autre type de séquence.

# %%
fruits = ["pomme", "banane", "orange"]
fruit_aleatoire = random.choice(fruits)
print(fruit_aleatoire)  # Affiche un fruit aléatoire de la liste
# Out:
# pomme

# %% [markdown]
#     Mélanger une liste aléatoirement:
#
# La fonction random.shuffle(sequence) mélange les éléments d'une liste aléatoirement.

# %%
cartes = ["As", "Roi", "Dame", "Valet", "10", "9", "8", "7", "6", "5", "4", "3", "2"]
random.shuffle(cartes)
print(cartes)  # Affiche la liste de cartes mélangée
# Out:
# ['Valet', 'Roi', '2', '6', '3', '5', 'As', 'Dame', '9', '10', '4', '7', '8']

# %% [markdown]
# ### Application

# %% [markdown]
# Réaliser un programme permettant de jouer au *jeu du juste prix*.
# Définir une variable accueillant un nombre aléatoire entre 1 et 100. >> fonction **random**
# Tant que l'utilisateur,
# - n'a pas trouvé, lui demander d'entrer un prix
# - s'il trouve, lui dire qu'il a gagner en N coup
# - sinon on affiche "c'est moins" ou "c'est plus".

# %%
import random

#choisir un nombre aléatoire entre 1 et 100.
just_price = random.randint(1, 100)
user_price = 0
coups = 0
while just_price != user_price:
    user_price = int(input("Entrer un prix : "))
    coups += 1
    if user_price < just_price:
        print("C'est plus")
    elif user_price > just_price:
        print("C'est moins")
    else:
        print("Gagné en ", coups, " coups !")
#Fin du jeu

# %% [markdown]
# ## Exercice 7

# %% [markdown]
# ### PREMIER NIVEAU DE DIFFICULTE :

# %% [markdown]
# Créer un script qui déterminera qui devra payer les croissants chaque semaine.
# Utiliser une **liste** contenant l'ensemble des participants dans la pièce
# Dans une boucle qui doit se réaliser pour toutes les semaines de l'année :
# - Générer un nombre aléatoire entre 0 et le nombre de personne dans la liste -1 pour savoir qui payera les croissants
# - Afficher qui devra payer les croissants.

# %%
#Premier niveau :
import random

participants = ["Godon", "Narayanan", "Gauthier", "Champalou",
                "Fissier", "Hermier", "Berliat","Guillier",
                "Le Brun", "Judas", "Gibbesi"]
for i in range(52):
    index_croissant = random.randint(0,len(participants)-1)
    print(participants[index_croissant])

# %% [markdown]
# ### Module time

# %% [markdown]
# Le module time est un module intégré à Python qui permet de travailler avec le temps. Il offre des fonctions pour obtenir l'heure actuelle, mesurer des intervalles de temps, mettre en pause l'exécution d'un programme, etc.
#
# Comment l'utiliser ?
#
#     Importer le module:
#
# Avant de pouvoir utiliser les fonctions de time, il faut l'importer dans votre code :

# %%
import time

# %% [markdown]
#    **Obtenir l'heure actuelle:**
#
#     time.time(): Renvoie le nombre de secondes écoulées depuis le 1er janvier 1970 (epoch) en tant que flottant.

# %%
timestamp = time.time()
print(timestamp)
# Out:
# 1739440784.129824

# %% [markdown]
#     time.localtime(): Renvoie une structure de données représentant l'heure locale actuelle.

# %%
heure_locale = time.localtime()
print(heure_locale)
# Out:
# time.struct_time(tm_year=2025, tm_mon=2, tm_mday=13, tm_hour=10, tm_min=59, tm_sec=45, tm_wday=3, tm_yday=44, tm_isdst=0)

# %% [markdown]
#     time.strftime(format, t): Formate une date et une heure selon un format spécifié.

# %%
heure_formatee = time.strftime("%H:%M:%S", time.localtime())
print(heure_formatee)  # Affiche l'heure au format HH:MM:SS
# Out:
# 10:59:49

# %% [markdown]
#    **Mesurer des intervalles de temps:**
#
#     time.sleep(seconds): Met en pause l'exécution du programme pendant un nombre spécifié de secondes.

# %%
print("Début")
time.sleep(2)
print("Fin")  # S'affichera après 2 secondes
# Out:
# Début
# Fin

# %% [markdown]
#     Pour mesurer le temps d'exécution d'un bloc de code, vous pouvez utiliser time.time() avant et après le bloc et calculer la différence.

# %%
debut = time.time()
# Code à mesurer
fin = time.time()
temps_execution = fin - debut
print(f"Temps d'exécution : {temps_execution} secondes")
# Out:
# Temps d'exécution : 0.0 secondes

# %% [markdown]
# ### DEUXIEME NIVEAU DE DIFFICULTE :

# %% [markdown]
# Créer un script qui déterminera qui devra payer les croissants la semaine prochaine.
# Utiliser une **liste** contenant l'ensemble des participants dans la pièce
# Dans une boucle qui doit se réaliser 1000 fois :
# - Générer un nombre aléatoire entre 0 et le nombre de personne dans la liste -1
# - Compter le nombre d'ocurrance pour chaque nom
# - *Afficher par personne le nombre de fois que le nom de la personne est tombé pour déterminer qui va payer les croissants*
# - Puis après avoir afficher un décompte de 5 secondes, afficher qui paiera les croissants.

# %%
#Deuxième niveau :
import random, time

participants = ["Godon", "Narayanan", "Gauthier", "Champalou",
                "Fissier", "Hermier", "Berliat","Guillier",
                "Le Brun", "Judas", "Gibbesi"]

resultats = {"Godon" : 0, "Narayanan" : 0, "Gauthier" : 0, "Champalou" : 0,
                "Fissier" : 0, "Hermier" : 0, "Berliat" : 0,"Guillier" : 0,
                "Le Brun" : 0, "Judas" : 0, "Gibbesi" : 0}

for i in range(1000):
    tirage = random.randint(0,len(participants)-1)
    prenom = participants[tirage]
    resultats[prenom] += 1

#for prenom, count in resultats.items():
 #   print(f"{prenom} a été sélectionné {count} fois.")

print("Compte à rebours de 5 secondes avant l'annonce de l'heureux gagnant !!!")

for i in range(5, 0, -1):
    print("Temps restant :", i, "secondes")
    time.sleep(1)

gagnant = max(resultats, key=resultats.get)

print("La personne qui paiera les croissants est : ", gagnant)
# Out:
# Compte à rebours de 5 secondes avant l'annonce de l'heureux gagnant !!!
# Temps restant : 5 secondes
# Temps restant : 4 secondes
# Temps restant : 3 secondes
# Temps restant : 2 secondes
# Temps restant : 1 secondes
# La personne qui paiera les croissants est :  Guillier

# %%
#Deuxième niveau :
import random, time

participants = ["Godon", "Narayanan", "Gauthier", "Champalou",
                "Fissier", "Hermier", "Berliat","Guillier",
                "Le Brun", "Judas", "Gibbesi"]

resultats = {"Godon" : 0, "Narayanan" : 0, "Gauthier" : 0, "Champalou" : 0,
                "Fissier" : 0, "Hermier" : 0, "Berliat" : 0,"Guillier" : 0,
                "Le Brun" : 0, "Judas" : 0, "Gibbesi" : 0}

for i in range(1000):
    tirage = random.choice(participants)
    resultats[tirage] += 1

#for prenom, count in resultats.items():
 #   print(f"{prenom} a été sélectionné {count} fois.")

print("Compte à rebours de 5 secondes avant l'annonce de l'heureux gagnant !!!")

for i in range(5, 0, -1):
    print("Temps restant :", i, "secondes")
    time.sleep(1)

gagnant = max(resultats, key=resultats.get)

print("La personne qui paiera les croissants est : ", gagnant)
# Out:
# Compte à rebours de 5 secondes avant l'annonce de l'heureux gagnant !!!
# Temps restant : 5 secondes
# Temps restant : 4 secondes
# Temps restant : 3 secondes
# Temps restant : 2 secondes
# Temps restant : 1 secondes
# La personne qui paiera les croissants est :  Berliat

# %% [markdown]
# ## Exercices entrainement

# %% [markdown]
# ### Niveau intermédiaire

# %% [markdown]
# 1. **Inventaire de magasin:**
#
#     * Créez un dictionnaire représentant l'inventaire d'un magasin. Les clés sont les noms des produits et les valeurs sont des tuples contenant le prix et la quantité en stock.
#     * Demandez à l'utilisateur de saisir le nom d'un produit.
#     * Utilisez un "if" pour vérifier si le produit est en stock.
#     * Si oui, affichez le prix et la quantité disponible.
#     * Si non, affichez un message indiquant que le produit est en rupture de stock.

# %%
inventaire = {
    "pommes": (1.50, 10),
    "bananes": (0.80, 20),
    "lait": (2.00, 5),
}

produit = input("Entrez le nom du produit : ")

if produit in inventaire:
    prix, quantite = inventaire[produit] # ici un tuple, dont les 2 valeurs sont assignées aux variables prix et quantité
    print(f"Prix : {prix}€, Quantité : {quantite}")
else:
    print("Produit en rupture de stock.")
# Out:
# Entrez le nom du produit : pommes
# Prix : 1.5€, Quantité : 10

# %% [markdown]
# 2. **Analyse de notes:**
#
#     * Créez une liste de tuples, chaque tuple représentant les notes d'un élève. Chaque tuple contient le nom de l'élève et une liste de ses notes.
#     * Utilisez une boucle "for" pour parcourir la liste d'élèves.
#     * Pour chaque élève, calculez la moyenne de ses notes et stockez-la dans un dictionnaire où la clé est le nom de l'élève et la valeur est sa moyenne.
#     * Affichez le dictionnaire des moyennes.

# %%
notes_eleves = [
    ("Alice", [15, 18, 16]),
    ("Bob", [12, 14, 17]),
    ("Charlie", [19, 20, 18]),
]

moyennes = {}

for nom, notes in notes_eleves:
    moyenne = sum(notes) / len(notes)
    moyennes[nom] = moyenne

print(moyennes)
# Out:
# {'Alice': 16.333333333333332, 'Bob': 14.333333333333334, 'Charlie': 19.0}
